# %%
import pandas as pd

# %%
file_path = "D://MLProjects//ZDatasets//AirlineData//Data_Train.csv"

# Read the CSV file
df = pd.read_csv(file_path)
df

# Read/Undestand the carefully
# Out:
#          Airline Date_of_Journey    Source Destination                  Route  \
# 0         IndiGo      24-03-2019  Banglore   New Delhi              BLR ? DEL
# 1      Air India      01-05-2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2    Jet Airways      09-06-2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3         IndiGo      12-05-2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4         IndiGo      01-03-2019  Banglore   New Delhi        BLR ? NAG ? DEL
# ..           ...             ...       ...         ...                    ...
# 245       IndiGo      24-04-2019  Banglore       Delhi              BLR ? DEL
# 246  Jet Airways      09-06-2019     Delhi      Cochin        DEL ? BOM ? COK
# 247       IndiGo      15-05-2019     Delhi      Cochin        DEL ? BOM ? COK
# 248      Vistara      27-06-2019   Chennai     Kolkata              MAA ? CCU
# 249     SpiceJet      06-06-2019     Delhi      Cochin        DEL ? PNQ ? COK
#
#     Dep_Time      Arrival_Time Duration Total_Stops  \
# 0      22:20  22-03-2023 01:10   2h 50m    non-stop
# 1      05:50             13:15   7h 25m     2 stops
# 2      09:25  10-06-2023 04:25      19h     2 stops
# 3      18:05             23:30   5h 25m      1 stop
# 4      16:50             21:35   4h 45m      1 stop
# ..       ...               ...      ...         ...
# 245    23:30  25-04-2023 02:20   2h 50m    non-stop
# 246    19:15  10-06-2023 04:25   9h 10m      1 stop
# 247    10:35             21:00  10h 25m      1 stop
# 248    17:45             20:05   2h 20m    non-stop
# 249    08:45             13:15   4h 30m      1 stop
#
#                  Additional_Info  Price
# 0                        No info   3897
# 1                        No info   7662
# 2                        No info  13882
# 3                        No info   6218
# 4                        No info  13302
# ..                           ...    ...
# 245                      No info   3943
# 246  In-flight meal not included  10577
# 247                      No info   6979
# 248                      No info  11982
# 249                      No info   5264
#
# [250 rows x 11 columns]

# %% [markdown]
# # Matplotlib

# %%
# HOw to install
# !pip install matplotlib

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# %%
# Bar Plot
# plt.bar(COL01,COL02)

plt.bar(df['Airline'],df['Price'])
plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])

plt.xticks(rotation=25)


plt.show()

# %%
# Apply Label

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)
plt.xlabel("Airline")
plt.ylabel("Price")
plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)

plt.xlabel("Airline")
plt.ylabel('Price')

plt.title("Airline Vs Price")

plt.show()

# %%
# Apply Title


plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)

plt.xlabel("Airline",fontsize=12)
plt.ylabel('Price',fontsize=12)

plt.title("Airline Vs Price",fontsize=20)

plt.show()

# %%
# Apply Title

plt.bar(df['Airline'],df['Price'])
plt.xlabel("Airline")
plt.ylabel('Price')
plt.title("Airline Vs Price")

plt.xticks(rotation=45)
plt.show()

# %%
# Apply FontSize
f = 15

plt.bar(df['Airline'],df['Price'])
plt.xticks(rotation=45)

plt.xlabel("Airline",fontsize=f)
plt.ylabel('Price',fontsize=f)
plt.title("Airline Vs Price",fontsize=f)
plt.show()

# %%
# Playing the parameters
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center')
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html


sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.8,align='center')

plt.xlabel("Airline",fontsize=f)
plt.ylabel('Price',fontsize=f)
plt.title("Airline Vs Price",fontsize=f)
plt.xticks(rotation=45)
plt.show()

# %%
# change Color
import matplotlib.pyplot as plt
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center',color='b')

plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.show()

# %%
# Color
import matplotlib.pyplot as plt
#colourValue = ['y','b','g','r','y','b','g','r']
colourValue = ['y','b','g','r','y','b','g','r']

# change Color
import matplotlib.pyplot as plt
sizeOfFont = 15
plt.bar(df['Airline'],df['Price'],width=.5,align='center',color=colourValue)

plt.xlabel("Airline",fontsize=sizeOfFont)
plt.ylabel('Price',fontsize=sizeOfFont)
plt.title("Airline Vs Price",fontsize=sizeOfFont)
plt.xticks(rotation=45)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Seaborn

# %%
# insall Seaborn
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shivraj shinde\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\shivraj shinde\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent')
plt.xticks(rotation=45)
plt.title("Airline Vs Price")
plt.show()
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'IndiGo'),
#   Text(1, 0, 'Air India'),
#   Text(2, 0, 'Jet Airways'),
#   Text(3, 0, 'SpiceJet'),
#   Text(4, 0, 'Multiple carriers'),
#   Text(5, 0, 'GoAir'),
#   Text(6, 0, 'Vistara'),
#   Text(7, 0, 'Air Asia')])

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'])
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\AppData\Local\Temp\ipykernel_11440\3644847344.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df['Airline'],y=df['Price'],palette='Accent',ci=None)

# %%
# sort OR arrange Alphabitically

import seaborn as sns
AirlinSortedList = ['Air Asia','Air India','GoAir','IndiGo','Jet Airways','Multiple carriers','SpiceJet','Vistara']

sns.barplot(x=df['Airline'],y=df['Price'],order=AirlinSortedList)
plt.xticks(rotation=45)
plt.show()

# %%
# plot graph based on Sorted Price

df01 = df.groupby('Airline')['Price'].sum()
df01_sorted = df01.sort_values(ascending=False)
df01 = pd.DataFrame({'Airline': df01_sorted.index, 'Price': df01_sorted.values})
df01
# Out:
#              Airline    Price
# 0        Jet Airways  1007932
# 1          Air India   373477
# 2  Multiple carriers   336367
# 3             IndiGo   272407
# 4            Vistara   109064
# 5           SpiceJet    65597
# 6              GoAir    57031
# 7           Air Asia    15658

# %%
sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x=df01['Airline'],y=df01['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()

# %%
# make plot horizontal

import seaborn as sns
sns.barplot(y=df['Airline'],x=df['Price'],palette='Accent',errorbar=None)
plt.xticks(rotation=45)
plt.show()

# %%
# Add Hue of Source Multivariate
import seaborn as sns

plt.figure(figsize=(12,3))

sns.barplot(x=df['Airline'] ,y=df['Price'],hue=df['Source'],errorbar=None)
plt.xticks(rotation=45,fontsize=14)
plt.yticks(fontsize=14)
plt.title("Airline with Source Vs Price",fontsize=20)
plt.show()

# %% [markdown]
# # CountPlot

# %%
# 
import seaborn as sns
plt.figure(figsize=(10,3))
sns.countplot(hue=df['Airline'],x=df['Source'])
plt.show()

# %%
# Line Plot

# %%
plt.figure(figsize=(8,3))
sns.lineplot(y=df['Price'],x=df['Airline'])
plt.xticks(rotation=25)
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.lineplot(y=df['Price'],x=df['Source'],hue=df['Airline'])
plt.show()

# %%
sns.scatterplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
plt.figure(figsize=(8,3))
sns.scatterplot(y=df['Price'],x=df['Airline'])
plt.xticks(rotation=25)
plt.show()

# %%
plt.figure(figsize=(12,3))
sns.swarmplot(y=df['Price'],x=df['Airline'])
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\SHIVRAJ SHINDE\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.boxplot(y=df['Price'],x=df['Airline'])
plt.show()

# %%
plt.figure(figsize=(12,3))
sns.violinplot(x=df['Price'])
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x=df['Price'],y=df['Airline'])
# Out:
# <Axes: xlabel='Price', ylabel='Airline'>

# %%
sns.histplot(df['Price'],kde=False)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>
