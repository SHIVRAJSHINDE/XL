# %%
import pandas as pd
df = pd.read_csv("D:\MLProjects\ZDatasets\LoanEligibilityTest\Churn_Modelling.csv")
df.head()
# Out:
#    RowNumber   Loan_ID  CustomerId   Surname     Designation     Education  \
# 0          1  LP001002    15634602  Hargrave        Ma nager      Graduate
# 1          2  LP001003    15647311      Hill  Senior Manager      Graduate
# 2          3  LP001005    15619304      Onio         Manager      Graduate
# 3          4  LP001006    15701354      Boni  Senior Manager  Not Graduate
# 4          5  LP001008    15737888  Mitchell         Manager      Graduate
#
#   Self_Employed  CreditScore  Credit_History Geography  ... NumOfProducts  \
# 0            No          619             1.0    France  ...             1
# 1            No          608             1.0     Spain  ...             1
# 2           Yes          502             1.0    France  ...             3
# 3            No          699             1.0    France  ...             2
# 4            No          850             1.0     Spain  ...             1
#
# ...

# %%
#  Drop the uncessary columns columns
# listOfColumns = ['RowNumber', 'Loan_ID', 'CustomerId','Surname','Credit_History']
# df.drop(listOfColumns,axis=1,inplace=True)

# %%
df
# Out:
#      RowNumber   Loan_ID  CustomerId   Surname     Designation     Education  \
# 0            1  LP001002    15634602  Hargrave        Ma nager      Graduate
# 1            2  LP001003    15647311      Hill  Senior Manager      Graduate
# 2            3  LP001005    15619304      Onio         Manager      Graduate
# 3            4  LP001006    15701354      Boni  Senior Manager  Not Graduate
# 4            5  LP001008    15737888  Mitchell         Manager      Graduate
# ..         ...       ...         ...       ...             ...           ...
# 609        610  LP002978    15586585    Duncan  Senior Manager      Graduate
# 610        611  LP002979    15686611      Moss         Manager      Graduate
# 611        612  LP002983    15603203  Avdeyeva             AVP      Graduate
# 612        613  LP002984    15619857  Crawford  Senior Manager      Graduate
# 613        614  LP002990    15805062    Lynton         Manager      Graduate
#
# ...

# %%
listOfColumns = ['RowNumber', 'Loan_ID', 'CustomerId','Surname','Credit_History']

def DropColumns(listOfColumns):
    df.drop(listOfColumns,axis=1,inplace=True)
    return df

df =  DropColumns(listOfColumns)
df
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0          Ma nager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 609  Senior Manager      Graduate            No          698   Germany
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 612  Senior Manager      Graduate            No          605    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
# Print Columns
# df.columns
df.columns
# Out:
# Index(['Designation', 'Education', 'Self_Employed', 'CreditScore', 'Geography',
#        'Property_Area', 'Married', 'Gender', 'Age', 'Tenure', 'Balance',
#        'HasCar', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Dependents',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'EstimatedSalary',
#        'Exited', 'Loan_Status'],
#       dtype='object')

# %%
# Print Unique Values
# df.nunique()

df.nunique()
# Out:
# Designation            7
# Education              2
# Self_Employed          2
# CreditScore          302
# Geography              3
# Property_Area          3
# Married                3
# Gender                 2
# Age                   56
# Tenure                11
# Balance              386
# HasCar                 2
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# Dependents             4
# ApplicantIncome      505
# CoapplicantIncome    287
# LoanAmount           203
# EstimatedSalary      614
# Exited                 2
# Loan_Status            2
# dtype: int64

# %%
# print the description of the data
# df.describe()
df.describe()
# Out:
#        CreditScore         Age      Tenure        Balance      HasCar  \
# count   614.000000  614.000000  614.000000     614.000000  614.000000
# mean    647.447883   38.555375    5.141694   74391.451775    0.718241
# std     100.298314   10.167730    2.975888   62542.651433    0.450223
# min     376.000000   19.000000    0.000000       0.000000    0.000000
# 25%     574.000000   32.000000    2.250000       0.000000    0.000000
# 50%     650.500000   37.000000    5.000000   95498.790000    1.000000
# 75%     721.000000   43.000000    8.000000  125846.997500    1.000000
# max     850.000000   80.000000   10.000000  213146.200000    1.000000
#
#        NumOfProducts   HasCrCard  IsActiveMember  ApplicantIncome  \
# count     614.000000  614.000000      614.000000       614.000000
# mean        1.537459    0.718241        0.500000      5403.459283
# std         0.580598    0.450223        0.500408      6109.041673
# min         1.000000    0.000000        0.000000       150.000000
# ...

# %%
df.head()
# Out:
#       Designation     Education Self_Employed  CreditScore Geography  \
# 0        Ma nager      Graduate            No          619    France
# 1  Senior Manager      Graduate            No          608     Spain
# 2         Manager      Graduate           Yes          502    France
# 3  Senior Manager  Not Graduate            No          699    France
# 4         Manager      Graduate            No          850     Spain
#
#   Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  HasCrCard  \
# 0         Urban        No  Female   42       2  ...              1          1
# 1         Rural  Divorced  Female   41       1  ...              1          0
# 2         Urban  Divorced  Female   42       8  ...              3          1
# 3         Urban  Divorced  Female   39       1  ...              2          0
# 4         Urban        No  Female   43       2  ...              1          1
#
#    IsActiveMember  Dependents  ApplicantIncome CoapplicantIncome  LoanAmount  \
# ...

# %%
df['Designation'].unique()
# Out:
# array(['Ma nager', 'Senior Manager', 'Manager', 'Executive', 'VP',
#        'Assistant Vice President', 'AVP'], dtype=object)

# %%
df['Designation'].value_counts()
# Out:
# Manager                     264
# Executive                   188
# Senior Manager               84
# VP                           31
# AVP                          21
# Ma nager                     15
# Assistant Vice President     11
# Name: Designation, dtype: int64

# %%
for i in df.columns:
    print()
    print(df[i].value_counts())
    print()
# Out:
# Manager                     264
# Executive                   188
# Senior Manager               84
# VP                           31
# AVP                          21
# Ma nager                     15
# Assistant Vice President     11
# Name: Designation, dtype: int64
#
#
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
#
#
# No     503
# Yes     82
# Name: Self_Employed, dtype: int64
#
#
# 850    13
# 687     8
# 605     6
# 684     5
# 616     5
#        ..
# 813     1
# 791     1
# 657     1
# 498     1
# 495     1
# Name: CreditScore, Length: 302, dtype: int64
#
#
# France     286
# Germany    166
# Spain      162
# Name: Geography, dtype: int64
#
#
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
#
#
# Divorced    252
# No          213
# Married     146
# Name: Married, dtype: int64
#
#
# Male      335
# Female    279
# Name: Gender, dtype: int64
#
#
# 34    33
# 35    32
# 37    30
# 36    29
# 38    29
# ...

# %%
for i in df.columns:
    print()
    print(df[i].value_counts())
    print()
# Out:
# Manager                     264
# Executive                   188
# Senior Manager               84
# VP                           31
# AVP                          21
# Ma nager                     15
# Assistant Vice President     11
# Name: Designation, dtype: int64
#
#
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
#
#
# No     503
# Yes     82
# Name: Self_Employed, dtype: int64
#
#
# 850    13
# 687     8
# 605     6
# 684     5
# 616     5
#        ..
# 813     1
# 791     1
# 657     1
# 498     1
# 495     1
# Name: CreditScore, Length: 302, dtype: int64
#
#
# France     286
# Germany    166
# Spain      162
# Name: Geography, dtype: int64
#
#
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
#
#
# Divorced    252
# No          213
# Married     146
# Name: Married, dtype: int64
#
#
# Male      335
# Female    279
# Name: Gender, dtype: int64
#
#
# 34    33
# 35    32
# 37    30
# 36    29
# 38    29
# ...

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df['Designation'].value_counts()
# Out:
# Manager                     264
# Executive                   188
# Senior Manager               84
# VP                           31
# AVP                          21
# Ma nager                     15
# Assistant Vice President     11
# Name: Designation, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Divorced    252
# No          213
# Married     146
# Name: Married, dtype: int64

# %%
#df['Dependents'].replace("3+",3,inplace=True)
#df['Dependents'].value_counts()

# %%
def ReplaceWithCorrectValue(colName,valueToRepalceDict):
    for valueToRepalce,newValue in valueToRepalceDict.items():
        df[colName].replace(valueToRepalce,newValue,inplace=True)
    return df

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
valueToRepalceDict={'3+':3}

ReplaceWithCorrectValue(colName='Dependents',valueToRepalceDict=valueToRepalceDict)

df
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0          Ma nager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 609  Senior Manager      Graduate            No          698   Germany
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 612  Senior Manager      Graduate            No          605    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
df['Dependents'].value_counts()
# Out:
# 0    345
# 1    102
# 2    101
# 3     51
# Name: Dependents, dtype: int64

# %%
df['Designation'].value_counts()
# Out:
# Manager                     264
# Executive                   188
# Senior Manager               84
# VP                           31
# AVP                          21
# Ma nager                     15
# Assistant Vice President     11
# Name: Designation, dtype: int64

# %%
valueToRepalceDict={'Assistant Vice President':'AVP','Ma nager': 'Manager'}

ReplaceWithCorrectValue(colName='Designation',valueToRepalceDict=valueToRepalceDict)

df['Designation'].value_counts()
# Out:
# Manager           279
# Executive         188
# Senior Manager     84
# AVP                32
# VP                 31
# Name: Designation, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Divorced    252
# No          213
# Married     146
# Name: Married, dtype: int64

# %%
valueToRepalceDict={'No':'Single'}

ReplaceWithCorrectValue(colName='Married',valueToRepalceDict=valueToRepalceDict)

df['Married'].value_counts()
# Out:
# Divorced    252
# Single      213
# Married     146
# Name: Married, dtype: int64

# %%
'''
def ReplaceWithCorrectValue(colName,valuesToReplace):
    for key,value in valuesToReplace.items():
        df[colName].replace(key,value,inplace=True)
    return df


ReplaceWithCorrectValue(colName='Dependents',valuesToReplace={'3+':3})
#ReplaceWithCorrectValue(colName='Loan_Status',valuesToReplace={'Y':1,'N':0})
ReplaceWithCorrectValue(colName='Designation',valuesToReplace={'Assistant Vice President':'AVP','Ma nager': 'Manager'})
ReplaceWithCorrectValue(colName='Married',valuesToReplace={'No':'Single'})
'''
# Out:
# "\ndef ReplaceWithCorrectValue(colName,valuesToReplace):\n    for key,value in valuesToReplace.items():\n        df[colName].replace(key,value,inplace=True)\n    return df\n\n\nReplaceWithCorrectValue(colName='Dependents',valuesToReplace={'3+':3})\n#ReplaceWithCorrectValue(colName='Loan_Status',valuesToReplace={'Y':1,'N':0})\nReplaceWithCorrectValue(colName='Designation',valuesToReplace={'Assistant Vice President':'AVP','Ma nager': 'Manager'})\nReplaceWithCorrectValue(colName='Married',valuesToReplace={'No':'Single'})\n"

# %%
# Find Null Value
df.isna().sum()
# Out:
# Designation           0
# Education             0
# Self_Employed        29
# CreditScore           0
# Geography             0
# Property_Area         0
# Married               3
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# HasCar                0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# Dependents           15
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# EstimatedSalary       0
# Exited                0
# Loan_Status           0
# dtype: int64

# %%
modeSelf_Employed = df['Self_Employed'].mode()[0] # most frequest
modeSelf_Employed
# Out:
# 'No'

# %%
df['Self_Employed'].fillna(modeSelf_Employed,inplace=True)

# %%
df['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
replaceMode = ['Self_Employed','Married','Dependents']

# %%
def replaceWithMode(columnName):
    for i in columnName:
        modeValue = df[i].mode()[0]
        # print(modeValue,i)
        df[i].fillna(modeValue,inplace=True)
    return df 

# Replacing the 'Self_Employed','Married' with mode  
columnName = replaceMode

df = replaceWithMode(columnName)

df
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0           Manager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 609  Senior Manager      Graduate            No          698   Germany
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 612  Senior Manager      Graduate            No          605    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
def replaceWithMean(columnName1):
    for i in columnName1:
        meanOfColumn = df[i].mean()
        df[i].fillna(meanOfColumn,inplace=True)
    return df 

columnName1 = ['LoanAmount']
df = replaceWithMean(columnName1)

df
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0           Manager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 609  Senior Manager      Graduate            No          698   Germany
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 612  Senior Manager      Graduate            No          605    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
df.isnull().sum()
# Out:
# Designation          0
# Education            0
# Self_Employed        0
# CreditScore          0
# Geography            0
# Property_Area        0
# Married              0
# Gender               0
# Age                  0
# Tenure               0
# Balance              0
# HasCar               0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# Dependents           0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# EstimatedSalary      0
# Exited               0
# Loan_Status          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# No dropping of duplcate sicne tehre were no duplicate values
# df.drop_duplicates()

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['Dependents'].value_counts()
# Out:
# 0    360
# 1    102
# 2    101
# 3     51
# Name: Dependents, dtype: int64

# %%
df[df['Dependents'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Designation, Education, Self_Employed, CreditScore, Geography, Property_Area, Married, Gender, Age, Tenure, Balance, HasCar, NumOfProducts, HasCrCard, IsActiveMember, Dependents, ApplicantIncome, CoapplicantIncome, LoanAmount, EstimatedSalary, Exited, Loan_Status]
# Index: []
#
# [0 rows x 22 columns]

# %%
# See categoricall Values

df.head().T
# Out:
#                             0               1          2               3  \
# Designation           Manager  Senior Manager    Manager  Senior Manager
# Education            Graduate        Graduate   Graduate    Not Graduate
# Self_Employed              No              No        Yes              No
# CreditScore               619             608        502             699
# Geography              France           Spain     France          France
# Property_Area           Urban           Rural      Urban           Urban
# Married                Single        Divorced   Divorced        Divorced
# Gender                 Female          Female     Female          Female
# Age                        42              41         42              39
# Tenure                      2               1          8               1
# Balance                   0.0        83807.86   159660.8             0.0
# HasCar                      1               0          1               0
# ...

# %%
# Categorical Columns
# Numerical Colums

# %%
ColCat  = ['Designation','Education','Self_Employed','Geography','Property_Area','Married','Gender']
for i in ColCat:
    print(df[i].value_counts())
    print()
# Out:
# Manager           279
# Executive         188
# Senior Manager     84
# AVP                32
# VP                 31
# Name: Designation, dtype: int64
#
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
#
# No     532
# Yes     82
# Name: Self_Employed, dtype: int64
#
# France     286
# Germany    166
# Spain      162
# Name: Geography, dtype: int64
#
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
#
# Divorced    255
# Single      213
# Married     146
# Name: Married, dtype: int64
#
# Male      335
# Female    279
# Name: Gender, dtype: int64

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

# %%
ColCat
# Out:
# ['Designation',
#  'Education',
#  'Self_Employed',
#  'Geography',
#  'Property_Area',
#  'Married',
#  'Gender']

# %%
# Visualizatoin

# %%
# Designation vs Loan Status

sns.countplot(x=df['Designation'],hue=df['Loan_Status'])
# Out:
# <Axes: xlabel='Designation', ylabel='count'>

# %%
# Education Vs Loan Status

sns.countplot(x=df['Education'],hue=df['Loan_Status'])
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
Columns  = ['Designation','Education','Self_Employed','Geography','Property_Area','Married','Gender']

for i,col in enumerate(Columns):
    print(i,col)
# Out:
# 0 Designation
# 1 Education
# 2 Self_Employed
# 3 Geography
# 4 Property_Area
# 5 Married
# 6 Gender

# %%
Columns  = ['Designation','Education','Self_Employed','Geography','Property_Area','Married','Gender']

plt.figure(figsize=(15,15))

for i,col in enumerate(Columns):
    plt.subplot(4,2,i+1)
    
    sns.countplot(x=df[col],hue=df['Loan_Status'])

plt.show()

# %%
CatFeature = ['Tenure','HasCar','NumOfProducts','HasCrCard','IsActiveMember','Dependents']

plt.figure(figsize=(15,15))
for i,col in enumerate(CatFeature):
    plt.subplot(3,2,i+1)
    sns.countplot(x=df[col],hue=df['Loan_Status'])

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 25))
for i, column in enumerate(Columns):

    plt.subplot(4, 2, i + 1)
    sns.countplot(x=df[column],hue=df['Loan_Status'])
    plt.xticks(rotation=15)  # Rotate x-axis labels by 45 degrees

plt.show()

# %%
df
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0           Manager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 609  Senior Manager      Graduate            No          698   Germany
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 612  Senior Manager      Graduate            No          605    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
# Loan Rejection
loanRejected = df[df['Loan_Status']=="N"]
loanRejected
# Out:
#         Designation     Education Self_Employed  CreditScore Geography  \
# 1    Senior Manager      Graduate            No          608     Spain
# 7    Senior Manager      Graduate            No          376   Germany
# 9           Manager      Graduate            No          684    France
# 13        Executive      Graduate            No          549    France
# 17        Executive      Graduate            No          549     Spain
# ..              ...           ...           ...          ...       ...
# 596         Manager  Not Graduate           Yes          685     Spain
# 597         Manager      Graduate            No          646   Germany
# 600  Senior Manager      Graduate            No          601    France
# 605         Manager  Not Graduate            No          601    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
loanRejected = loanRejected.groupby('Designation').count()
loanRejected
# Out:
#                 Education  Self_Employed  CreditScore  Geography  \
# Designation
# AVP                    11             11           11         11
# Executive              59             59           59         59
# Manager                89             89           89         89
# Senior Manager         22             22           22         22
# VP                     11             11           11         11
#
#                 Property_Area  Married  Gender  Age  Tenure  Balance  ...  \
# Designation                                                           ...
# AVP                        11       11      11   11      11       11  ...
# Executive                  59       59      59   59      59       59  ...
# Manager                    89       89      89   89      89       89  ...
# Senior Manager             22       22      22   22      22       22  ...
# VP                         11       11      11   11      11       11  ...
#
# ...

# %%
loanRejected = pd.DataFrame(loanRejected['Loan_Status'])
loanRejected
# Out:
#                 Loan_Status
# Designation
# AVP                      11
# Executive                59
# Manager                  89
# Senior Manager           22
# VP                       11

# %%
loanRejected.reset_index(inplace=True)

# %%
loanRejected
# Out:
#       Designation  Loan_Status
# 0             AVP           11
# 1       Executive           59
# 2         Manager           89
# 3  Senior Manager           22
# 4              VP           11

# %%
loanRejected
plt.pie(loanRejected['Loan_Status'],labels=loanRejected['Designation'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x246193d4950>,
# ...
#  [Text(1.0822306057515834, 0.19691855162620187, 'AVP'),
#   Text(0.26727822286933245, 1.0670343722579005, 'Executive'),
#   Text(-0.9044950946157754, -0.6260100828389265, 'Manager'),
#   Text(0.82702370900361, -0.7252804869468862, 'Senior Manager'),
#   Text(1.0822305873147333, -0.19691865295194302, 'VP')],
#  [Text(0.5903076031372272, 0.10741011906883736, '5.7%'),
#   Text(0.1457881215650904, 0.5820187485043092, '30.7%'),
#   Text(-0.4933609606995138, -0.34146004518486894, '46.4%'),
#   Text(0.4511038412746963, -0.39560753833466517, '11.5%'),
#   Text(0.5903075930807635, -0.10741017433742346, '5.7%')])

# %%
loanAccepted = df[df['Loan_Status']=="Y"]
loanAccepted = loanAccepted.groupby('Designation').count()
loanAccepted = pd.DataFrame(loanAccepted['Loan_Status'])
loanAccepted.reset_index(inplace=True)

plt.pie(loanAccepted['Loan_Status'],labels=loanAccepted['Designation'],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x246194b0b10>,
# ...
#  [Text(1.0865849765403184, 0.17126905370462003, 'AVP'),
#   Text(0.3227398937188937, 1.0515887794201293, 'Executive'),
#   Text(-0.9620375897457506, -0.5333701115699931, 'Manager'),
#   Text(0.7978178317882808, -0.7572890513407985, 'Senior Manager'),
#   Text(1.08782986929309, -0.163175290634884, 'VP')],
#  [Text(0.5926827144765372, 0.09341948383888365, '5.0%'),
#   Text(0.17603994202848747, 0.5735938796837069, '30.6%'),
#   Text(-0.5247477762249548, -0.2909291517654508, '45.0%'),
#   Text(0.4351733627936077, -0.41306675527679915, '14.7%'),
#   Text(0.5933617468871399, -0.089004703982664, '4.7%')])

# %%
loanAccepted = df[df['Designation']=="Y"]

# %%
NumericalFeatures = ['CreditScore','Age','Tenure','Balance','HasCar','NumOfProducts','HasCrCard',
                     'IsActiveMember','Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary','Loan_Status']

NumericalFeaturesDf = df[NumericalFeatures]
NumericalFeaturesDf

NumericalFeatures = ['CreditScore','Age','Balance','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary']

NumericalFeaturesDf = df[NumericalFeatures]
NumericalFeaturesDf
# Out:
#      CreditScore  Age    Balance  ApplicantIncome  CoapplicantIncome  \
# 0            619   42       0.00             5849                0.0
# 1            608   41   83807.86             4583             1508.0
# 2            502   42  159660.80             3000                0.0
# 3            699   39       0.00             2583             2358.0
# 4            850   43  125510.82             6000                0.0
# ..           ...  ...        ...              ...                ...
# 609          698   51  111018.98             2900                0.0
# 610          495   30  129755.99             4106                0.0
# 611          650   27       0.00             8072              240.0
# 612          605   64  129555.70             7583                0.0
# 613          667   38   87202.38             4583                0.0
#
#      LoanAmount  EstimatedSalary
# 0    146.412162        101348.88
# 1    128.000000        112542.58
# 2     66.000000        113931.57
# ...

# %%
NumericalFeatures

plt.figure(figsize=(10,8))
sns.heatmap(NumericalFeaturesDf.corr(),cmap="YlGnBu", annot=True)
# Out:
# <Axes: >

# %%
NumericalFeaturesDf.cov()
# Out:
#                      CreditScore           Age       Balance  ApplicantIncome  \
# CreditScore         10059.751765     -5.069703  2.470909e+05     5.837707e+03
# Age                    -5.069703    103.382736 -9.252593e+03    -2.279368e+03
# Balance            247090.896023  -9252.593500  3.911583e+09     2.382268e+07
# ApplicantIncome      5837.707499  -2279.368052  2.382268e+07     3.732039e+07
# CoapplicantIncome   -6713.091864    746.447019 -5.680287e+06    -2.084490e+06
# LoanAmount            350.342952    -13.363972  3.442053e+05     2.903830e+05
# EstimatedSalary    325529.954357 -24016.510793 -1.270379e+08    -4.717035e+06
#
#                    CoapplicantIncome     LoanAmount  EstimatedSalary
# CreditScore            -6.713092e+03     350.342952     3.255300e+05
# Age                     7.464470e+02     -13.363972    -2.401651e+04
# Balance                -5.680287e+06  344205.262106    -1.270379e+08
# ApplicantIncome        -2.084490e+06  290382.976853    -4.717035e+06
# ...

# %%
# CHECK DISTIBUTION

# %%
sns.scatterplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(df['CreditScore'])
# Out:
# <Axes: ylabel='CreditScore'>

# %%
df[['CreditScore','Age','Balance','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary']]
# Out:
#      CreditScore  Age    Balance  ApplicantIncome  CoapplicantIncome  \
# 0            619   42       0.00             5849                0.0
# 1            608   41   83807.86             4583             1508.0
# 2            502   42  159660.80             3000                0.0
# 3            699   39       0.00             2583             2358.0
# 4            850   43  125510.82             6000                0.0
# ..           ...  ...        ...              ...                ...
# 609          698   51  111018.98             2900                0.0
# 610          495   30  129755.99             4106                0.0
# 611          650   27       0.00             8072              240.0
# 612          605   64  129555.70             7583                0.0
# 613          667   38   87202.38             4583                0.0
#
#      LoanAmount  EstimatedSalary
# 0    146.412162        101348.88
# 1    128.000000        112542.58
# 2     66.000000        113931.57
# ...

# %%
NumericalFeatures = ['CreditScore','Age','Balance','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary']

plt.figure(figsize=(15,15))
for i,col in enumerate(NumericalFeatures):
    plt.subplot(4,2,i+1)
    sns.scatterplot(df[col])


plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(x=df['Designation'],y=df['Age'])
# Out:
# <Axes: xlabel='Designation', ylabel='Age'>

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(x=df['Designation'],y=df['Age'],hue=df['Loan_Status'])
# Out:
# <Axes: xlabel='Designation', ylabel='Age'>

# %%
plt.figure(figsize=(15,30))
for i, column in enumerate(Columns):

    plt.subplot(7, 1, i + 1)
    sns.swarmplot(x=df[column],y=df['Age'],hue=df['Loan_Status'],dodge=True)    
    plt.xticks(rotation=15)  # Rotate x-axis labels by 45 degrees

plt.show()

# %%
Columns
# Out:
# ['Designation',
#  'Education',
#  'Self_Employed',
#  'Geography',
#  'Property_Area',
#  'Married',
#  'Gender']

# %%
NumericalFeaturesDf.skew()
# Out:
# CreditScore         -0.098198
# Age                  1.077993
# Balance             -0.074452
# ApplicantIncome      6.539513
# CoapplicantIncome    7.491531
# LoanAmount           2.726601
# EstimatedSalary     -0.011657
# dtype: float64

# %%
sns.distplot(NumericalFeaturesDf['CreditScore'])
# Out:
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
NumericalFeatures1 = ['CreditScore','Age','Tenure','Balance','HasCar','NumOfProducts','HasCrCard',
                     'IsActiveMember','Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary','Loan_Status']
NumericalFeatures = ['CreditScore','Age','Balance','ApplicantIncome','CoapplicantIncome','LoanAmount','EstimatedSalary']
NumericalFeatures

CatFeature = ['Tenure','HasCar','NumOfProducts','HasCrCard','IsActiveMember','Dependents']

print(NumericalFeatures)
print(CatFeature)
# Out:
# ['CreditScore', 'Age', 'Balance', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'EstimatedSalary']
# ['Tenure', 'HasCar', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Dependents']

# %%
plt.figure(figsize=(15,15))
for i in enumerate(NumericalFeatures):
    plt.subplot(4,4,i[0]+1)
    sns.distplot(df[i[1]])

# %%
plt.figure(figsize=(15,20))

for i, column in enumerate(NumericalFeatures):
    plt.subplot(4, 2, i + 1)
    sns.distplot(x=df[column])
    plt.xlabel(column)

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
plt.figure(figsize=(5,5))
for i in enumerate(NumericalFeatures):
    sns.boxplot(df[i[1]])

# %%
NumericalFeatures
# Out:
# ['CreditScore',
#  'Age',
#  'Balance',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'EstimatedSalary']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def checkOutlier(NumericalFeatures,df):
    plt.figure(figsize=(15, 5))

    for i, feature in enumerate(NumericalFeatures):
        plt.subplot(1, len(NumericalFeatures), i+1)
        sns.boxplot(df[feature])
        plt.xlabel(feature,rotation=45)  # Set x-label as feature name

    plt.ylabel('Values')  # Set y-label

    plt.tight_layout()
    plt.show()


checkOutlier(NumericalFeatures,df)

# %%
'''LowerQuantile= .35
HigherQuantile= .75

q1 = df['Age'].quantile(LowerQuantile)

q3 = df['Age'].quantile(HigherQuantile)
print(q1)
print(q3)
IQR = q3-q1

IQR

lowerLimit = q1-1.5*IQR 
upperLimit = q3+1.5*IQR
print("-------------------")
print(lowerLimit)
print(upperLimit)

condtion = df['Age']>upperLimit
higherOutlier = df[condtion]

higherOutlier
'''
# Out:
# 34.0
# 44.0
# -------------------
# 19.0
# 59.0
#         Designation     Education Self_Employed  CreditScore Geography  \
# 42        Executive      Graduate            No          556    France
# 44          Manager  Not Graduate           Yes          660     Spain
# 85        Executive      Graduate            No          652     Spain
# 104  Senior Manager      Graduate            No          670     Spain
# 158         Manager      Graduate            No          646    France
# 181  Senior Manager      Graduate            No          510    France
# 230       Executive      Graduate            No          673    France
# 234       Executive      Graduate            No          585    France
# 243         Manager      Graduate           Yes          659   Germany
# 252         Manager  Not Graduate           Yes          681    France
# 276       Executive      Graduate            No          756    France
# ...

# %%
def removeOutlier(colName,df,LowerQuantile,HigherQuantile):
    # checkOutlier(NumericalFeatures,df)
    # plt.figure(figsize=(10,10))
    # sns.boxplot(y =df[colName])

    q1 = df[colName].quantile(LowerQuantile)
    q3 = df[colName].quantile(HigherQuantile)

    IQR = q3-q1

    lowerLimit = q1-1.5*IQR 
    upperLimit = q3+1.5*IQR

    print(q1)
    print(q3)
    print(IQR)
    print(lowerLimit)
    print(upperLimit)
    
    higherOutlier = df[df[colName]>upperLimit]
    lowerOutlier = df[df[colName]<lowerLimit]

    df = df.drop(higherOutlier.index,axis=0)
    df = df.drop(lowerOutlier.index,axis=0)
    
    checkOutlier(NumericalFeatures,df)

    return df

# %%
df = removeOutlier(colName='Age',df=df,LowerQuantile=.30,HigherQuantile=.60)
df
# Out:
# 33.0
# 39.0
# 6.0
# 24.0
# 48.0
#         Designation     Education Self_Employed  CreditScore Geography  \
# 0           Manager      Graduate            No          619    France
# 1    Senior Manager      Graduate            No          608     Spain
# 2           Manager      Graduate           Yes          502    France
# 3    Senior Manager  Not Graduate            No          699    France
# 4           Manager      Graduate            No          850     Spain
# ..              ...           ...           ...          ...       ...
# 607       Executive  Not Graduate            No          584    France
# 608  Senior Manager      Graduate            No          699    France
# 610         Manager      Graduate            No          495    France
# 611             AVP      Graduate            No          650    France
# 613         Manager      Graduate           Yes          667     Spain
#
#     Property_Area   Married  Gender  Age  Tenure  ...  NumOfProducts  \
# ...

# %%
LowerQuantile= .30
HigherQuantile= .80

q1 = df['ApplicantIncome'].quantile(LowerQuantile)

q3 = df['ApplicantIncome'].quantile(HigherQuantile)
print(q1)
print(q3)
IQR = q3-q1

IQR

lowerLimit = q1-1.5*IQR 
upperLimit = q3+1.5*IQR
print("-------------------")
print(lowerLimit)
print(upperLimit)
# Out:
# 2964.3
# 5705.0
# -------------------
# -1146.749999999999
# 9816.05

# %%
df = removeOutlier(colName='ApplicantIncome',df=df,LowerQuantile=.30,HigherQuantile=.80)
# Out:
# 2964.3
# 5705.0
# 2740.7
# -1146.749999999999
# 9816.05

# %%
LowerQuantile= .30
HigherQuantile= .80

q1 = df['LoanAmount'].quantile(LowerQuantile)

q3 = df['LoanAmount'].quantile(HigherQuantile)
print(q1)
print(q3)
IQR = q3-q1

IQR

lowerLimit = q1-1.5*IQR 
upperLimit = q3+1.5*IQR
print("-------------------")
print(lowerLimit)
print(upperLimit)
# Out:
# 106.4
# 160.40000000000003
# -------------------
# 25.399999999999963
# 241.4000000000001

# %%
df = removeOutlier(colName='CoapplicantIncome',df=df,LowerQuantile=.30,HigherQuantile=.90)
# Out:
# 0.0
# 3822.7999999999993
# 3822.7999999999993
# -5734.199999999999
# 9556.999999999998

# %%
df = removeOutlier(colName='LoanAmount',df=df,LowerQuantile=.30,HigherQuantile=.80)
# Out:
# 106.4
# 160.40000000000003
# 54.00000000000003
# 25.399999999999963
# 241.4000000000001
