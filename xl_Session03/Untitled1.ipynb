# %% [markdown]
# <style>
#     table {
#         width: 100%;
#         border-collapse: collapse;
#         margin: 20px 0;
#         border-radius: 10px;
#         overflow: hidden;
#         box-shadow: 0 4px 10px rgba(0, 0, 0, 0.1);
#     }
#     th {
#         background-color: #ff5722; /* Orange Header */
#         color: white;
#         padding: 10px;
#     }
#     td {
#         padding: 12px;
#         border-bottom: 1px solid #ddd;
#     }
#     tr:nth-child(even) {
#         background-color: #f2f2f2;
#     }
#     tr:nth-child(odd) {
#         background-color: #f9f9f9;
#     }
#     tr:hover {
#         background-color: #ffecb3;
#     }
#     td:nth-child(2) {
#         background-color: #e1bee7; /* Light Purple for Operation column */
#     }
#     td:nth-child(3) {
#         background-color: #81d4fa; /* Light Blue for List column */
#     }
#     td:nth-child(4) {
#         background-color: #a5d6a7; /* Light Green for Tuple column */
#     }
#     td:nth-child(5) {
#         background-color: #ef9a9a; /* Light Red for Set column */
#     }
# </style>
#
# <table>
#     <thead>
#         <tr>
#             <th>Main Operation</th>
#             <th>Operation</th>
#             <th>List</th>
#             <th>Tuple</th>
#             <th>Set</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Mutable</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>No</td>
#             <td>Yes</td>
#         </tr>
#         <tr>
#             <td>Hold Duplicate Members</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>No</td>
#         </tr>
#         <tr>
#             <td>Ordered</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>No</td>
#         </tr>
#         <tr>
#             <td>Indexed</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>Yes</td>
#             <td>No</td>
#         </tr>
#         <tr>
#             <td>Creation</td>
#             <td></td>
#             <td></td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>Simple Method</td>
#             <td>abc = ["apple", "banana", "cherry", "orange"]</td>
#             <td>thistple = ("apple", "banana", "cherry", "orange")</td>
#             <td>myset = {"apple", "banana", "cherry", "orange"}</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>By Using Constructor</td>
#             <td>abc = list(("apple", "banana", "cherry", "orange"))</td>
#             <td>thistple = tuple(("apple", "banana", "cherry", "orange"))</td>
#             <td>myset = set(("apple", "banana", "cherry", "orange"))</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>Length</td>
#             <td>len(abc)</td>
#             <td>len(thistple)</td>
#             <td>len(myset)</td>
#         </tr>
#         <tr>
#             <td>Check if Item Exists</td>
#             <td></td>
#             <td>if "apple" in abc:</td>
#             <td>if "apple" in thistple:</td>
#             <td>if "apple" in myset:</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>print("Yes, apple is in the fruits list")</td>
#             <td>print("Yes, apple is in the fruits list")</td>
#             <td>print("Yes, apple is in the set")</td>
#         </tr>
#         <tr>
#             <td>Changing the Item</td>
#             <td></td>
#             <td>abc[1] = "blackcurrant"</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>Adding an Item</td>
#             <td>To Add at the Last Index</td>
#             <td>abc.append("orange")</td>
#             <td></td>
#             <td>myset.add("orange")</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>To Add at a Specified Index</td>
#             <td>abc.insert(1, "orange")</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>Remove</td>
#             <td>To Remove a Specified Item</td>
#             <td>abc.remove("banana")</td>
#             <td></td>
#             <td>myset.remove("banana")</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>To Remove the Last Item</td>
#             <td>abc.pop()</td>
#             <td></td>
#             <td>myset.pop()</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>To Remove by Index</td>
#             <td>abc.pop(1)</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>To Remove by Index</td>
#             <td>del abc[0]</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>Empty or Delete</td>
#             <td>Clear</td>
#             <td>abc.clear()</td>
#             <td>Tuples cannot be emptied</td>
#             <td>myset.clear()</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>Delete</td>
#             <td>del abc</td>
#             <td>del thistple</td>
#             <td>del myset</td>
#         </tr>
#         <tr>
#             <td>Copy</td>
#             <td>Deep Copy</td>
#             <td>myList.copy()</td>
#             <td>Tuples cannot be copied</td>
#             <td>mySet.copy()</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td>Shallow Copy</td>
#             <td>newList = myList</td>
#             <td></td>
#             <td>newSet = mySet</td>
#         </tr>
#         <tr>
#             <td>Convert</td>
#             <td></td>
#             <td>list()</td>
#             <td>tuple()</td>
#             <td>set()</td>
#         </tr>
#         <tr>
#             <td>Join</td>
#             <td></td>
#             <td>list3 = list1 + list2</td>
#             <td>ddd = abc + xyz</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>list1.extend(list2)</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td></td>
#             <td></td>
#             <td>set1.union(set2)</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td></td>
#             <td></td>
#             <td>s1.update(s2)</td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>for x in list2:</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>list1.append(x)</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>print(list1)</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td>Reverses the Order</td>
#             <td></td>
#             <td>list1[::-1]</td>
#             <td>tup[::-1]</td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>list1.reverse()</td>
#             <td>tup.reverse()</td>
#             <td></
#        <tr>
#             <td>Sorts the List</td>
#             <td></td>
#             <td>list1.sort()</td>
#             <td></td>
#             <td></td>
#         </tr>
#         <tr>
#             <td></td>
#             <td></td>
#             <td>sorted()</td>
#             <

# %%
# Out:
# 30
